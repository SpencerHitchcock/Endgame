# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd
from html.parser import HTMLParser

# %%
names = {'Iron-Man',
        'Incredible-Hulk-The',
        'Thor',
        'Iron-Man-2',
        'Captain-America-The-First-Avenger',
        'Avengers-The-(2012)',
        'Iron-Man-3',s
        'Thor-The-Dark-World',
        'Captain-America-The-Winter-Soldier',
        'Guardians-of-the-Galaxy',
        'Avengers-Age-of-Ultron',
        'Ant-Man',
        'Captain-America-Civil-War',
        'Doctor-Strange-(2016)',
        'Guardians-of-the-Galaxy-Vol-2',
        'Spider-Man-Homecoming',
        'Thor-Ragnarok',
        'Black-Panther',
        'Avengers-Infinity-War',
        'Ant-Man-and-the-Wasp',
        'Captain-Marvel-(2019)',
        'Avengers-Endgame-(2019)'
         }

# %%
track=0
for name in names:
    track+=1
    print(name)
    data = requests.get('https://www.the-numbers.com/movie/' + name + '#tab=box-office')
    soup = BeautifulSoup(data.text, 'html.parser')
    div = soup.find('div' , {'id': 'box_office_chart'})
    table = div.find('table')
    tbody = table.find('tbody')
    html = table.encode(encoding='ISO-8859-1')
    dfs = pd.read_html(html,header=0)
    df = dfs[0]
    df['movie'] = name
    df.to_csv('movie'+str(track)+'.csv', encoding='ISO-8859-1')
    print(name)
df
# Out:
# Incredible-Hulk-The
# Incredible-Hulk-The
# Ant-Man-and-the-Wasp
# Ant-Man-and-the-Wasp
# Avengers-Age-of-Ultron
# Avengers-Age-of-Ultron
# Iron-Man
# Iron-Man
# Captain-America-The-Winter-Soldier
# Captain-America-The-Winter-Soldier
# Thor-Ragnarok
# Thor-Ragnarok
# Spider-Man-Homecoming
# Spider-Man-Homecoming
# Black-Panther
# Black-Panther
# Captain-America-The-First-Avenger
# Captain-America-The-First-Avenger
# Avengers-Endgame-(2019)
# Avengers-Endgame-(2019)
# Ant-Man
# Ant-Man
# Guardians-of-the-Galaxy-Vol-2
# Guardians-of-the-Galaxy-Vol-2
# Iron-Man-2
# Iron-Man-2
# Captain-America-Civil-War
# Captain-America-Civil-War
# Thor
# Thor
# Avengers-The-(2012)
# Avengers-The-(2012)
# Avengers-Infinity-War
# Avengers-Infinity-War
# Guardians-of-the-Galaxy
# Guardians-of-the-Galaxy
# Thor-The-Dark-World
# Thor-The-Dark-World
# Captain-Marvel-(2019)
# Captain-Marvel-(2019)
# Iron-Man-3
# Iron-Man-3
# Doctor-Strange-(2016)
# Doctor-Strange-(2016)
#             Date  Rank        Gross % Change  Theaters Per Theater  \
# 0    Nov 4, 2016     1  $85,058,311      NaN      3882     $21,911
# 1   Nov 11, 2016     1  $42,970,065     -49%      3882     $11,069
# 2   Nov 18, 2016     2  $17,761,060     -59%      3694      $4,808
# 3   Nov 25, 2016     3  $13,737,945     -23%      3008      $4,567
# 4    Dec 2, 2016     5   $6,684,552     -51%      2935      $2,278
# 5    Dec 9, 2016     5   $4,535,827     -32%      2763      $1,642
# 6   Dec 16, 2016     9   $2,210,912     -51%      1930      $1,146
# 7   Dec 23, 2016    17     $722,988     -67%       631      $1,146
# 8   Dec 30, 2016    19     $646,480     -11%       466      $1,387
# 9    Jan 6, 2017    23     $307,088     -52%       263      $1,168
# 10  Jan 13, 2017    28     $206,640     -33%       162      $1,276
# 11  Jan 20, 2017    30     $134,795     -35%       132      $1,021
# 12  Jan 27, 2017    39     $108,654     -19%       104      $1,045
# 13   Feb 3, 2017    30     $237,287    +118%       190      $1,249
# 14  Feb 10, 2017    33     $186,539     -21%       171      $1,091
# 15  Feb 17, 2017    39     $124,514     -33%       136        $916
# 16  Feb 24, 2017    40      $81,957     -34%       105        $781
# 17   Mar 3, 2017    46      $45,195     -45%        81        $558
# 18  Mar 10, 2017    55      $18,198     -60%        47        $387
#
#      Total Gross  Week                  movie
# 0    $85,058,311     1  Doctor-Strange-(2016)
# 1   $152,952,234     2  Doctor-Strange-(2016)
# 2   $181,627,937     3  Doctor-Strange-(2016)
# 3   $205,778,872     4  Doctor-Strange-(2016)
# 4   $215,507,729     5  Doctor-Strange-(2016)
# 5   $222,267,273     6  Doctor-Strange-(2016)
# 6   $226,260,939     7  Doctor-Strange-(2016)
# 7   $228,341,954     8  Doctor-Strange-(2016)
# 8   $230,107,790     9  Doctor-Strange-(2016)
# 9   $230,898,006    10  Doctor-Strange-(2016)
# 10  $231,242,048    11  Doctor-Strange-(2016)
# 11  $231,480,175    12  Doctor-Strange-(2016)
# 12  $231,639,787    13  Doctor-Strange-(2016)
# 13  $231,910,330    14  Doctor-Strange-(2016)
# 14  $232,185,345    15  Doctor-Strange-(2016)
# 15  $232,382,905    16  Doctor-Strange-(2016)
# 16  $232,526,983    17  Doctor-Strange-(2016)
# 17  $232,597,113    18  Doctor-Strange-(2016)
# 18  $232,630,718    19  Doctor-Strange-(2016)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2296e2ddcdd4> in <module>
# ----> 1 Iron-Man-3
#
# NameError: name 'Iron' is not defined
